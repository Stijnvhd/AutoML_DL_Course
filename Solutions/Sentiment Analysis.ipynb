# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\Oreilly\Reddit_Data.csv', encoding='latin-1')
df.head(5)
# Out:
#                                        clean_comment  category
# 0   family mormon have never tried explain them t...         1
# 1  buddhism has very much lot compatible with chr...         1
# 2  seriously don say thing first all they won get...        -1
# 3  what you have learned yours and only yours wha...         0
# 4  for your own benefit you may want read living ...         1

# %%
from sklearn.model_selection import train_test_split
from autoviml.Auto_NLP import Auto_NLP
train, test = train_test_split(df, test_size=0.2)
# Out:
# Imported Auto_ViML version: 0.1.684. Call using:
#              m, feats, trainm, testm = Auto_ViML(train, target, test,
#                             sample_submission='',
#                             scoring_parameter='', KMeans_Featurizer=False,
#                             hyper_param='RS',feature_reduction=True,
#                              Boosting_Flag='CatBoost', Binning_Flag=False,
#                             Add_Poly=0, Stacking_Flag=False,Imbalanced_Flag=False,
#                             verbose=1)
#
#
# Imported Auto_NLP version: 0.0.47.. Call using:
#      train_nlp, test_nlp, nlp_pipeline, predictions = Auto_NLP(
#                 nlp_column, train, test, target, score_type='balanced_accuracy',
#                 modeltype='Classification',top_num_features=200, verbose=0,
#                 build_model=True)
# <style>.container { width:95% !important; }</style>

# %%
input_feature, target = "clean_comment", "category"

# %%
train_x, test_x, final, predicted= Auto_NLP(input_feature, train, test,target,score_type="balanced_accuracy",top_num_features=100,modeltype="Classification", verbose=2, build_model=True)
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\stopwords.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\omw.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet31.zip.
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# Auto NLP processing on NLP Column: clean_comment
# Shape of Train Data: 29799 rows
#     Shape of Test Data: 7450 rows
#     Added 9 summary columns for counts of words and characters in each row
# Cleaning text in Train data for clean_comment column
#     Faster text processing using clean_text function, since top_num_features is below 300
#     Time Taken for Expanding emojis and abbreviations in data = 91 seconds
#         Time Taken for Processing text in data = 219 seconds
# Train data Text cleaning completed. Time taken = 321 seconds
#
# For target = category
#
#     For class = -1
# Top 200 n-grams
# : ['fuck', 'what', 'not', 'they', 'but', 'bjp', 'modi', 'do', 'will', 'like', 'people', 'shit', 'india', 'why', 'how', 'don', 'there', 'now', 'who', 'go', 'bad', 'think', 'these', 'make', 'would', 'congress', 'their', 'see', 'even', 'when', 'time', 'them', 'thing', 'know', 'his', 'should', 'your', 'indian', 'country', 'take', 'come', 'look', 'mean', 'party', 'give', 'hate', 'here', 'guy', 'him', 'because', 'wrong', 'news', 'need', 'way', 'year', 'which', 'our', 'vote', 'use', 'day', 'want', 'someone', 'much', 'election', 'well', 'after', 'good', 'also', 'right', 'medium', 'work', 'stupid', 'try', 'government', 'post', 'really', 'sorry', 'game', 'hard', 'money', 'back', 'something', 'let', 'idiot', 'before', 'man', 'call', 'state', 'least', 'hindu', 'anything', 'never', 'show', 'long', 'big', 'doesn', 'read', 'start', 'power', 'cow', 'could', 'every', 'against', 'happen', 'sad', 'actually', 'muslim', 'talk', 'pakistan', 'fake', 'political', 'where', 'off', 'lot', 'life', 'black', 'disgust', 'comment', 'anyone', 'ever', 'keep', 'support', 'seem', 'may', 'issue', 'while', 'politician', 'tell', 'win', 'stop', 'lose', 'kill', 'please', 'what fuck', 'do not', 'look like', 'what do', 'holy shit', 'fake news', 'black money', 'people who', 'not sure', 'not good', 'prime minister', 'what wrong', 'rahul gandhi', 'don know', 'social medium', 'but not', 'vote bjp', 'they will', 'don think', 'not even', 'bad thing', 'political party', 'they not', 'those who', 'know what', 'right now', 'they don', 'do mean', 'what happen', 'don like', 'bjp will', 'these people', 'common man', 'bad thing happen', 'lok sabha election', 'what do mean', 'not sure how', 'do not know', 'don know what', 'look like they', 'as far know', 'what fuck happen', 'why guy hate', 'why should give', 'credit where due', 'lose their life', 'frequently ask question', 'long long time', 'look like bjp', 'not like india', 'not sure what', 'they will not', 'come back power', 'what people think', 'but don think', 'what happen when', 'item credit sr', 'news item credit', 'bharat mata jai', 'when ask his', 'there people who', 'what fuck they', 'who don know', 'don really care', 'they come power', 'they do not']
#     Top n-grams that are most frequent in this class are: 199
#
#     For class = 0
# Top 200 n-grams
# : ['what', 'modi', 'will', 'not', 'do', 'bjp', 'like', 'india', 'they', 'why', 'who', 'hai', 'errorintext', 'how', 'now', 'time', 'but', 'should', 'don', 'there', 'his', 'look', 'people', 'make', 'your', 'when', 'think', 'indian', 'come', 'here', 'would', 'guy', 'go', 'know', 'congress', 'give', 'him', 'want', 'need', 'vote', 'namo', 'where', 'party', 'see', 'thing', 'ban', 'man', 'take', 'even', 'someone', 'well', 'please', 'them', 'their', 'lot', 'because', 'thank', 'year', 'aap', 'back', 'wait', 'our', 'ppr', 'use', 'government', 'video', 'let', 'which', 'work', 'start', 'these', 'anti', 'election', 'doesn', 'register', 'post', 'something', 'next', 'call', 'team', 'happen', 'change', 'before', 'anyone', 'lose', 'trump', 'big', 'after', 'source', 'today', 'yes', 'pay', 'already', 'never', 'news', 'hope', 'stop', 'pakistan', 'bhi', 'democracy', 'way', 'standard', 'modiji', 'didn', 'become', 'end', 'show', 'kill', 'name', 'try', 'she', 'also', 'forget', 'isn', 'country', 'state', 'national', 'twitter', 'off', 'mein', 'read', 'chutiya', 'comment', 'add', 'minister', 'keep', 'reddit', 'point', 'wonder', 'watch', 'link', 'power', 'kejriwal', 'look like', 'anti national', 'team ppr', 'do not', 'amit shah', 'what happen', 'prime minister', 'rahul gandhi', 'how do', 'political party', 'what do', 'register register', 'will not', 'know what', 'today learn', 'why do', 'people who', 'raha hai', 'come back', 'bjp leader', 'standard score', 'why not', 'don know', 'acche din', 'hai kya', 'anyone else', 'don even', 'team standard', 'vance mcdonald', 'when they', 'someone please', 'india will', 'rha hai', 'don know why', 'lot lot lot', 'movie movie movie', 'they do not', 'waah modiji waah', 'wah modiji wah', 'what happen when', 'gayi hai gormint', 'also what your', 'amit shah not', 'amit shah will', 'anyone explain what', 'as soon possible', 'bill clinton rapist', 'bjp will lose', 'call him feku', 'chutiya chutiya chutiya', 'come back power', 'come home tell', 'do not know', 'don care our', 'don even understand', 'don even want', 'don like see', 'dosti ban rahe', 'ease do business', 'frequently ask question', 'kuch nahi hoga', 'look like dick', 'look like indian', 'make fool themselves', 'modi anti india', 'modi coward psychopath']
#     Top n-grams that are most frequent in this class are: 199
#
#     For class = 1
# Top 200 n-grams
# : ['good', 'not', 'but', 'they', 'like', 'what', 'will', 'people', 'do', 'india', 'modi', 'bjp', 'there', 'how', 'now', 'would', 'make', 'who', 'their', 'think', 'don', 'see', 'well', 'great', 'time', 'right', 'much', 'laugh', 'your', 'when', 'know', 'win', 'thing', 'why', 'really', 'his', 'even', 'need', 'them', 'take', 'want', 'best', 'go', 'here', 'indian', 'should', 'because', 'loud', 'come', 'country', 'way', 'many', 'post', 'look', 'love', 'our', 'first', 'work', 'congress', 'these', 'him', 'give', 'thanks', 'year', 'party', 'which', 'also', 'new', 'guy', 'election', 'vote', 'use', 'day', 'after', 'sure', 'where', 'true', 'nice', 'let', 'something', 'real', 'hope', 'government', 'world', 'state', 'start', 'try', 'pretty', 'lot', 'medium', 'live', 'back', 'become', 'could', 'power', 'those', 'doesn', 'point', 'happen', 'man', 'free', 'long', 'off', 'kind', 'talk', 'show', 'against', 'feel', 'news', 'actually', 'put', 'ask', 'top', 'keep', 'every', 'find', 'big', 'someone', 'change', 'old', 'call', 'never', 'mean', 'support', 'job', 'wow', 'seem', 'shit', 'before', 'last', 'though', 'anyone', 'read', 'laugh loud', 'look like', 'right now', 'do not', 'people who', 'as off', 'don know', 'laugh as', 'social medium', 'they will', 'how much', 'many people', 'encyclopedia team', 'free encyclopedia', 'what happen', 'how many', 'good job', 'good thing', 'prime minister', 'pretty sure', 'but not', 'they don', 'will not', 'last year', 'right wing', 'they do', 'good luck', 'political party', 'because they', 'know what', 'seem like', 'don think', 'not even', 'laugh as off', 'free encyclopedia team', 'would love see', 'bjp will win', 'do not mean', 'don understand why', 'do not know', 'lok sabha election', 'don know what', 'do good job', 'minister narendra modi', 'prime minister narendra', 'encyclopedia team reach', 'encyclopedia team sport', 'modi come power', 'what they do', 'what your opinion', 'do good work', 'bharat mata jai', 'don know why', 'reach free encyclopedia', 'team reach free', 'what happen when', 'good good good', 'best overall submitter', 'what would happen', 'roll floor laughing', 'not do anything', 'don know how', 'there plan make', 'know how many', 'how many year', 'universal basic income']
#     Top n-grams that are most frequent in this class are: 199
# Time Taken = 2 seconds
# ##################    THIS IS FOR BUILD_MODEL = TRUE           #################
# Building Model and Pipeline for NLP column = clean_comment. This will take time...
#        Class  -> Counts -> Percent
#           -1:    6655  ->   22.3%
#            0:   10504  ->   35.2%
#            1:   12640  ->   42.4%
#     Selected the maximum number of features limit = 76906
# Performing RandomizedSearchCV across 30 params. Optimizing for accuracy
#     Using train data = (23839,) and Cross Validation data = (5960,)
# Using a Calibrated Classifier in this Multi_Classification dataset to improve results...
# Since top_num_features = 100, Multinomial NB model selected. If you need different model, increase it >= 300.
# Training completed. Time taken for training = 19.0 minutes
# Best Params of NLP pipeline are: {'multinomialnb__alpha': 0.1525691058087889, 'selectkbest__k': 33285, 'tfidfvectorizer__binary': False, 'tfidfvectorizer__encoding': 'latin-1', 'tfidfvectorizer__max_df': 0.7700376305434805}
# <style>.container { width:95% !important; }</style>
# <style>.container { width:95% !important; }</style>
#   Now transforming Train data to return as output...
#     Time Taken for Expanding emojis and abbreviations in data = 110 seconds
#         Time Taken for Processing text in data = 199 seconds
#   Transforming Test data to return as output...
#     Time Taken for Expanding emojis and abbreviations in data = 30 seconds
#         Time Taken for Processing text in data = 50 seconds
# Training best Auto_NLP Pipeline on full Train data...will be faster since best params are known
#     Time Taken for Expanding emojis and abbreviations in data = 58 seconds
#         Time Taken for Processing text in data = 209 seconds
#     Returning best Auto_NLP pipeline to transform and make predictions on test data...
#     Time Taken for Expanding emojis and abbreviations in data = 18 seconds
#         Time Taken for Processing text in data = 40 seconds
# Training completed. Time taken for Auto_NLP = 38.8 minutes
# #########          A U T O   N L P  C O M P L E T E D    ###############################

# %%
final.predict(test_x[input_feature])
# Out:
#     Time Taken for Expanding emojis and abbreviations in data = 32 seconds
#         Time Taken for Processing text in data = 57 seconds
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)
